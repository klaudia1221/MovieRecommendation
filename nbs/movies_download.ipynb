# %% [markdown]
# # Do czego służy?
#
# Ta część służy do testowania bibliotek dotyczących filmów

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Utils

# %%
## !pip install imdbpy -required for download movies posters

# %%
# only once

# %%
import movies_utils as m

#path = m.small_download()

# %%
mv = m.get_movies(m.small_path)

# %%
m.set_movie_info(mv[:2])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:05<00:00,  3.12s/it]
#    movieId      title                                       genres  imdbId  \
# 0        1  Toy Story  Adventure|Animation|Children|Comedy|Fantasy  114709
# 1        2    Jumanji                   Adventure|Children|Fantasy  113497
#
#    tmdbId                                              cover  \
# 0   862.0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  8844.0  https://m.media-amazon.com/images/M/MV5BZTk2Zm...
#
#          full-title    year       director                 producer  \
# 0  Toy Story (1995)  1995.0  John Lasseter  Pixar Animation Studios
# 1    Jumanji (1995)  1995.0   Joe Johnston         TriStar Pictures
#
#                                          small-cover  \
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BZTk2Zm...
#
# ...

# %%
print(mv.loc[0])
m.img_show(mv.loc[0,'cover'])  # Toy Story
# Out:
# movieId                                                    1
# title                                       Toy Story (1995)
# genres           Adventure|Animation|Children|Comedy|Fantasy
# imdbId                                                114709
# tmdbId                                                   862
# cover      https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# Name: 0, dtype: object

# %% [markdown]
# # second one - set input data for server

# %%
import movies_utils as m

# %%
# after we donlowad a data we can 
# join them by movieId with tyoutube and remove empty values

m.generate_input()
# Out:
# saved to movie_input.csv
# this fields are not exported
#       Unnamed: 0  movieId title_x                      genres   imdbId  \
# 583          585      720     NaN  Adventure,Animation,Comedy   118114
# 838          843     1107   Loser                      Comedy   102336
# 4924        4959     7541     NaN              Comedy,Romance   214388
# 4926        4961     7561     NaN     Fantasy,Horror,Thriller    98061
# 4927        4962     7562     NaN                Action,Crime   118996
# 6013        6068    40955     NaN                Comedy,Drama   411195
# 7525        7600    86668     NaN                 Documentary  1347439
#
#         tmdbId cover    full-title    year    director producer small-cover  \
# 583   503475.0   NaN           NaN     NaN         NaN      NaN         NaN
# 838        NaN   NaN  Loser (1991)  1991.0  Erik Burke      NaN         NaN
# 4924   10035.0   NaN           NaN     NaN         NaN      NaN         NaN
# ...
